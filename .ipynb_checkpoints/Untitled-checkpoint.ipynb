# %%
import pandas as pd
import numpy as np
import sqlite3 
import math
import matplotlib.pyplot as plt
import sklearn
import scipy.stats as stats
con = sqlite3.connect('output/database.sqlite')
data = pd.read_sql('SELECT UNITID, INSTNM, cast(SAT_AVG as int)SAT_AVG, cast(ACTENMID as int)ACTENMID, cast(ACTMTMID as int)ACTMTMID, \
                  cast(ACTWRMID as int)ACTWRMID, cast(TUITIONFEE_PROG as int)TUITIONFEE_PROG, cast(MD_EARN_WNE_P10 as int)MD_EARN_WNE_P10,\
                  cast(UNEMP_RATE as int) UNEMP_RATE, cast(MD_EARN_WNE_P6 as int)MD_EARN_WNE_P6 , CONTROL from Scorecard', con)
df_copy = data.copy()
df_copy
# Out:
#           UNITID                                             INSTNM  SAT_AVG  \
# 0         100636                 COMMUNITY COLLEGE OF THE AIR FORCE      NaN
# 1         100654                           ALABAMA A & M UNIVERSITY      NaN
# 2         100663                UNIVERSITY OF ALABAMA AT BIRMINGHAM      NaN
# 3         100672             ALABAMA AVIATION AND TECHNICAL COLLEGE      NaN
# 4         100690                      SOUTHERN CHRISTIAN UNIVERSITY      NaN
# 5         100706                UNIVERSITY OF ALABAMA IN HUNTSVILLE      NaN
# 6         100724                           ALABAMA STATE UNIVERSITY      NaN
# 7         100751                          THE UNIVERSITY OF ALABAMA      NaN
# 8         100760                  CENTRAL ALABAMA COMMUNITY COLLEGE      NaN
# 9         100812                               ATHENS STATE COLLEGE      NaN
# 10        100830                    AUBURN UNIVERSITY AT MONTGOMERY      NaN
# 11        100858                      AUBURN UNIVERSITY MAIN CAMPUS      NaN
# 12        100919                   BESSEMER STATE TECHNICAL COLLEGE      NaN
# 13        100937                        BIRMINGHAM SOUTHERN COLLEGE      NaN
# 14        100964       BEVILL STATE COMMUNITY COLLEGE-BREWER CAMPUS      NaN
# 15        101019                  CHARLES ACADEMY OF BEAUTY CULTURE      NaN
# 16        101028             CHATTAHOOCHEE VALLEY COMMUNITY COLLEGE      NaN
# 17        101037            CHAUNCEY SPARKS STATE TECHNICAL COLLEGE      NaN
# 18        101073                                  CONCORDIA COLLEGE      NaN
# 19        101107          DOUGLAS MACARTHUR STATE TECHNICAL COLLEGE      NaN
# 20        101116                           DRAUGHONS JUNIOR COLLEGE      NaN
# 21        101143                    ENTERPRISE STATE JUNIOR COLLEGE      NaN
# 22        101161           JAMES H FAULKNER STATE COMMUNITY COLLEGE      NaN
# 23        101189                                FAULKNER UNIVERSITY      NaN
# 24        101198                     FAULKNER UNIVERSITY-BIRMINGHAM      NaN
# 25        101204                       FAULKNER UNIVERSITY-FLORENCE      NaN
# 26        101213                     FAULKNER UNIVERSITY-HUNTSVILLE      NaN
# 27        101231                           GADSDEN BUSINESS COLLEGE      NaN
# 28        101240                    GADSDEN STATE COMMUNITY COLLEGE      NaN
# 29        101268                  GADSDEN BUSINESS COLLEGE-ANNISTON      NaN
# ...          ...                                                ...      ...
# 124669  45897302                            Strayer University-Katy      NaN
# 124670  45897303               Strayer University-Northwest Houston      NaN
# 124671  45897304                           Strayer University-Plano      NaN
# 124672  45897305                      Strayer University-Cedar Hill      NaN
# 124673  45897306                    Strayer University-North Dallas      NaN
# 124674  45897307                     Strayer University-San Antonio      NaN
# 124675  45897308                        Strayer University-Stafford      NaN
# 124676  45920401                                     Unitek College      NaN
# 124677  46163401     Twin Rivers Adult School - Grand Avenue Center      NaN
# 124678  46163402    Twin Rivers Adult School - Arnold Avenue Center      NaN
# 124679  46163403                    Greater Sacramento Urban League      NaN
# 124680  46163404                                              I-TAP      NaN
# 124681  47647001                                    WestMed College      NaN
# 124682  47657701                              Excel Learning Center      NaN
# 124683  47657702                              Excel Learning Center      NaN
# 124684  47691101          SAE Institute of Technology San Francisco      NaN
# 124685  47701101              Strayer University-Bloomington Campus      NaN
# 124686  47702001               Strayer University-Schaumburg Campus      NaN
# 124687  47702002            Strayer University-Downers Grove Campus      NaN
# 124688  47702003                   Strayer University-Aurora Campus      NaN
# 124689  48065701                  Rasmussen College - Overland Park      NaN
# 124690  48154401  National Personal Training Institute of Cleveland      NaN
# 124691  48158001              Strayer University-St Louis-Brentwood      NaN
# 124692  48285701            Georgia Military College-Augusta Campus      NaN
# 124693  48285702           Georgia Military College-Fairburn Campus      NaN
# 124694  48285703           Georgia Military College-Columbus Campus      NaN
# 124695  48285704           Georgia Military College-Valdosta Campus      NaN
# 124696  48285705      Georgia Military College-Warner Robins Campus      NaN
# 124697  48285706                    Georgia Military College-Online      NaN
# 124698  48285707            Georgia Military College-Stone Mountain      NaN
#
#         ACTENMID  ACTMTMID  ACTWRMID  TUITIONFEE_PROG  MD_EARN_WNE_P10  \
# 0            NaN       NaN       NaN              NaN              NaN
# 1            NaN       NaN       NaN              NaN              NaN
# 2            NaN       NaN       NaN              NaN              NaN
# 3            NaN       NaN       NaN              NaN              NaN
# 4            NaN       NaN       NaN              NaN              NaN
# 5            NaN       NaN       NaN              NaN              NaN
# 6            NaN       NaN       NaN              NaN              NaN
# 7            NaN       NaN       NaN              NaN              NaN
# 8            NaN       NaN       NaN              NaN              NaN
# 9            NaN       NaN       NaN              NaN              NaN
# 10           NaN       NaN       NaN              NaN              NaN
# 11           NaN       NaN       NaN              NaN              NaN
# 12           NaN       NaN       NaN              NaN              NaN
# 13           NaN       NaN       NaN              NaN              NaN
# 14           NaN       NaN       NaN              NaN              NaN
# 15           NaN       NaN       NaN              NaN              NaN
# 16           NaN       NaN       NaN              NaN              NaN
# 17           NaN       NaN       NaN              NaN              NaN
# 18           NaN       NaN       NaN              NaN              NaN
# 19           NaN       NaN       NaN              NaN              NaN
# 20           NaN       NaN       NaN              NaN              NaN
# 21           NaN       NaN       NaN              NaN              NaN
# 22           NaN       NaN       NaN              NaN              NaN
# 23           NaN       NaN       NaN              NaN              NaN
# 24           NaN       NaN       NaN              NaN              NaN
# 25           NaN       NaN       NaN              NaN              NaN
# 26           NaN       NaN       NaN              NaN              NaN
# 27           NaN       NaN       NaN              NaN              NaN
# 28           NaN       NaN       NaN              NaN              NaN
# 29           NaN       NaN       NaN              NaN              NaN
# ...          ...       ...       ...              ...              ...
# 124669       NaN       NaN       NaN              NaN              NaN
# 124670       NaN       NaN       NaN              NaN              NaN
# 124671       NaN       NaN       NaN              NaN              NaN
# 124672       NaN       NaN       NaN              NaN              NaN
# 124673       NaN       NaN       NaN              NaN              NaN
# 124674       NaN       NaN       NaN              NaN              NaN
# 124675       NaN       NaN       NaN              NaN              NaN
# 124676       NaN       NaN       NaN              NaN              NaN
# 124677       NaN       NaN       NaN           4784.0              NaN
# 124678       NaN       NaN       NaN          22000.0              NaN
# 124679       NaN       NaN       NaN           2495.0              NaN
# 124680       NaN       NaN       NaN          15500.0              NaN
# 124681       NaN       NaN       NaN          30615.0              NaN
# 124682       NaN       NaN       NaN          14450.0              NaN
# 124683       NaN       NaN       NaN          14450.0              NaN
# 124684       NaN       NaN       NaN          17900.0              NaN
# 124685       NaN       NaN       NaN              NaN              NaN
# 124686       NaN       NaN       NaN              NaN              NaN
# 124687       NaN       NaN       NaN              NaN              NaN
# 124688       NaN       NaN       NaN              NaN              NaN
# 124689       NaN       NaN       NaN              NaN              NaN
# 124690       NaN       NaN       NaN              NaN              NaN
# 124691       NaN       NaN       NaN              NaN              NaN
# 124692       NaN       NaN       NaN              NaN              NaN
# 124693       NaN       NaN       NaN              NaN              NaN
# 124694       NaN       NaN       NaN              NaN              NaN
# 124695       NaN       NaN       NaN              NaN              NaN
# 124696       NaN       NaN       NaN              NaN              NaN
# 124697       NaN       NaN       NaN              NaN              NaN
# 124698       NaN       NaN       NaN              NaN              NaN
#
#         UNEMP_RATE  MD_EARN_WNE_P6             CONTROL
# 0              NaN             NaN              Public
# 1              NaN             NaN              Public
# 2              NaN             NaN              Public
# 3              NaN             NaN              Public
# 4              NaN             NaN   Private nonprofit
# 5              NaN             NaN              Public
# 6              NaN             NaN              Public
# 7              NaN             NaN              Public
# 8              NaN             NaN              Public
# 9              NaN             NaN              Public
# 10             NaN             NaN              Public
# 11             NaN             NaN              Public
# 12             NaN             NaN              Public
# 13             NaN             NaN   Private nonprofit
# 14             NaN             NaN              Public
# 15             NaN             NaN  Private for-profit
# 16             NaN             NaN              Public
# 17             NaN             NaN              Public
# 18             NaN             NaN   Private nonprofit
# 19             NaN             NaN              Public
# 20             NaN             NaN  Private for-profit
# 21             NaN             NaN              Public
# 22             NaN             NaN              Public
# 23             NaN             NaN   Private nonprofit
# 24             NaN             NaN   Private nonprofit
# 25             NaN             NaN   Private nonprofit
# 26             NaN             NaN   Private nonprofit
# 27             NaN             NaN  Private for-profit
# 28             NaN             NaN              Public
# 29             NaN             NaN  Private for-profit
# ...            ...             ...                 ...
# 124669         NaN             NaN  Private for-profit
# 124670         NaN             NaN  Private for-profit
# 124671         NaN             NaN  Private for-profit
# 124672         NaN             NaN  Private for-profit
# 124673         NaN             NaN  Private for-profit
# 124674         NaN             NaN  Private for-profit
# 124675         NaN             NaN  Private for-profit
# 124676         NaN             NaN  Private for-profit
# 124677         NaN             NaN              Public
# 124678         NaN             NaN              Public
# 124679         NaN             NaN              Public
# 124680         NaN             NaN              Public
# 124681         NaN             NaN   Private nonprofit
# 124682         NaN             NaN  Private for-profit
# 124683         NaN             NaN  Private for-profit
# 124684         NaN             NaN  Private for-profit
# 124685         NaN             NaN  Private for-profit
# 124686         NaN             NaN  Private for-profit
# 124687         NaN             NaN  Private for-profit
# 124688         NaN             NaN  Private for-profit
# 124689         NaN             NaN  Private for-profit
# 124690         NaN             NaN  Private for-profit
# 124691         NaN             NaN  Private for-profit
# 124692         NaN             NaN              Public
# 124693         NaN             NaN              Public
# 124694         NaN             NaN              Public
# 124695         NaN             NaN              Public
# 124696         NaN             NaN              Public
# 124697         NaN             NaN              Public
# 124698         NaN             NaN              Public
#
# [124699 rows x 11 columns]

# %%
Sat_6yEarn = df_copy[(df_copy.SAT_AVG > 0) & (df_copy.MD_EARN_WNE_P6 > 0) ]
plt.scatter(Sat_6yEarn['SAT_AVG'], Sat_6yEarn['MD_EARN_WNE_P6'])
plt.xlabel('SAT_AVG')
plt.ylabel('MD_EARN_WNE_P6')
plt.show()

# %%
#find if Tuition fee affect Earning
Tui_6yEarn = df_copy[(df_copy.TUITIONFEE_PROG > 0) & (df_copy.MD_EARN_WNE_P6 > 0) ]
plt.scatter(Tui_6yEarn['TUITIONFEE_PROG'], Tui_6yEarn['MD_EARN_WNE_P6'])
plt.xlabel('TUITIONFEE_PROG')
plt.ylabel('MD_EARN_WNE_P6')
plt.show()
#not quite, and hard to see as most of the tuition fee fall in the lower range

# %%
Sat3_6yEarn = df_copy[(df_copy.ACTENMID > 0)  & (df_copy.ACTMTMID > 0) & (df_copy.ACTWRMID > 0) & (df_copy.MD_EARN_WNE_P6 > 0) ]
acs = Sat3_6yEarn.sort_values(['ACTENMID', 'ACTMTMID', 'ACTWRMID'], ascending = False).head(10)
des = Sat3_6yEarn.sort_values(['ACTENMID', 'ACTMTMID', 'ACTWRMID'], ascending = True).head(10)
top = plt.plot(acs['MD_EARN_WNE_P6'],'ro', label="top")
btn = plt.plot(des['MD_EARN_WNE_P6'],'bo', label="btn")  
plt.legend()
plt.show()
#red mean the top 10 SAT score in read, writing and english
#blue mean the least 10 SAT score in read, writing and english
#clearly we can know that red earn high than blue

# %%
public = df_copy[(df_copy.CONTROL == 'Public')]
private_np = df_copy[(df_copy.CONTROL == 'Private nonprofit')]
private_p = df_copy[(df_copy.CONTROL == 'Private for-profit')]
public = public[public.MD_EARN_WNE_P6 > 0]
private_np = private_np[private_np.MD_EARN_WNE_P6 > 0]
private_p = private_p[private_p.MD_EARN_WNE_P6 > 0]
x = sum(public['MD_EARN_WNE_P6'])/len(public)
y = sum(private_np['MD_EARN_WNE_P6'])/len(private_np)
z = sum(private_p['MD_EARN_WNE_P6'])/len(private_p)
dictionary = plt.figure()

D = {u'Public':x, u'Private for non profit': y, u'Private for profit':z}

plt.bar(range(len(D)), D.values(), align='center')
plt.xticks(range(len(D)), D.keys())
plt.show()

# %%
linear_data = df_copy.copy()
linear_data = linear_data[(linear_data.ACTENMID > 0)  & (linear_data.ACTMTMID > 0) & (linear_data.ACTWRMID > 0) & (linear_data['MD_EARN_WNE_P6']>0)]
linear_data = linear_data[['ACTENMID', 'ACTMTMID', 'ACTWRMID','MD_EARN_WNE_P6']]

from sklearn.linear_model import LinearRegression
x = linear_data.drop('MD_EARN_WNE_P6' , axis = 1)
lm = LinearRegression()
lm.fit(x,linear_data.MD_EARN_WNE_P6)

print ('Estimated intercept', len(lm.coef_))
a = pd.DataFrame(list(zip(x.columns, lm.coef_)), columns = ['f', 'est'])
#since SAT math is the highest corelation, hence we plot SAT math


plt.scatter(linear_data.ACTMTMID, linear_data.MD_EARN_WNE_P6)
plt.xlabel("Math SAT score")
plt.ylabel("Earning in 6 years")
plt.title("Relationship between Math SAT score and Earning in 6 years(actual)")
plt.show()
# Out:
# Estimated intercept 3

# %%
lm.predict(x)[0:328]
plt.scatter(linear_data.ACTMTMID, lm.predict(x))


plt.xlabel("Math SAT score")
plt.ylabel("Earning in 6 years")
plt.title("Relationship between Math SAT score and Earning in 6 years(predict)")
plt.show()

# %%
import sklearn.cross_validation
x_train, x_test, y_train, y_test = sklearn.cross_validation.train_test_split(x, linear_data.MD_EARN_WNE_P6, test_size = 0.33, random_state = 5)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (219, 3)
# (109, 3)
# (219,)
# (109,)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
pred_train = lm.predict(x_train)
pred_test = lm.predict(x_test)

# %%
print("Train mean square error:", np.mean((y_train - lm.predict(x_train)) ** 2))
print("Test mean square error:", np.mean((y_test - lm.predict(x_test)) ** 2))
# Out:
# Train mean square error: 39191974.76090162
# Test mean square error: 42488041.97791103

# %%
plt.scatter(lm.predict(x_train),lm.predict(x_train) - y_train, c='b', s=40, alpha=0.5)
plt.scatter(lm.predict(x_test),lm.predict(x_test) - y_test, c='g', s=40)
plt.hlines(y = 0, xmin=0, xmax = 70000)
plt.title('Error Rate')
plt.ylabel('Error rate for training and testing set')
plt.show()

#most of it scatter around 0, good!

# %%
from sklearn import linear_model
import numpy as np



lm = linear_model.LinearRegression()
lm.fit(x_train, y_train)
pred_test = lm.predict(x_test)


fit = np.polyfit(x['ACTMTMID'],linear_data.MD_EARN_WNE_P6,1)
p = np.poly1d(fit)


plt.plot(x['ACTMTMID'], linear_data.MD_EARN_WNE_P6, 'ro')

xp = np.linspace(15, 35, 50)
orange = plt.plot(xp, p(xp), '-')


plt.xlabel("sat[MATH]")
plt.ylabel("Earning")
plt.show()

# %%
fit = np.polyfit(x_test['ACTMTMID'],lm.predict(x_test),1)
p = np.poly1d(fit)

plt.plot(x_test['ACTMTMID'], lm.predict(x_test1), 'ro')
xp = np.linspace(15, 35, 50)
orange = plt.plot(xp, p(xp), '-')

plt.xlabel("sat[MATH]")
plt.ylabel("Earning")
plt.show()

# %%
print("Mean square error for the model is:", np.mean((y_test - lm.predict(x_test)) ** 2)) 
print("The estimated coeficient of English is: ", lm.coef_[0])
print("The estimated coeficient of Math is: ", lm.coef_[1])
print("The estimated coeficient of Writing is: ", lm.coef_[2])
# Out:
# Mean square error for the model is: 42488041.97791103
# The estimated coeficient of English is:  -1076.09957108
# The estimated coeficient of Math is:  2811.35207771
# The estimated coeficient of Writing is:  223.65933888
